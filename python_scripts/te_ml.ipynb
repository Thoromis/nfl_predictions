# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

# %%
x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te = nfl_ml.start_ml_pipeline(Units.TE.KEY,
                                                                                                           random_search=False,
                                                                                                           unbalanced=True,
                                                                                                           scale_data=True)
utils.persist_train_test_split(x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te,
                               Units.TE.KEY)
# Out:
# Started ML pipeline for TE
# Classification counts for the data:
# Training data: Classification_All
# Bust                  370
# Good                    9
# dtype: int64
# Test data: Classification_All
# Bust                  122
# Good                    5
# dtype: int64
# AFTER RESAMPLING: Classification counts for the data:
# Training data: Classification_All
# Bust                  370
# Good                  370
# dtype: int64
# Test data: Classification_All
# Bust                  122
# Good                    5
# dtype: int64
# Scaling input data around 0
# Running GridSearchCV for Baseline_best.
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Running GridSearchCV for Baseline_MostFrequent.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for SVC.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for NearestNeighbors.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ...

# %%
x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te = utils.read_train_test_split(
    Units.TE.KEY)
nfl_vis.visualise_models(x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te, Units.TE.KEY)
# Out:
# Starting model evaluation for TE
# Plotting some stats for model/params combination: Baseline_best{'strategy': 'most_frequent'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# ...
