# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te = nfl_ml.start_ml_pipeline(Units.TE.KEY, random_search=True)
utils.persist_train_test_split(x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te, Units.TE.KEY)
# Out:
# Started ML pipeline for TE
# Classification counts for the data:
# Training data: Classification_All
# Good                  11
# Bust                   6
# dtype: int64
# Test data: Classification_All
# Good                  5
# Bust                  1
# dtype: int64
# Running RandomizedSearchCV for Baseline.
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# Running RandomizedSearchCV for SVC.
# Fitting 3 folds for each of 7 candidates, totalling 21 fits
# [CV] END ................................C=0.001, kernel=rbf; total time=   0.0s
# [CV] END ................................C=0.001, kernel=rbf; total time=   0.0s
# [CV] END ................................C=0.001, kernel=rbf; total time=   0.0s
# [CV] END .................................C=0.01, kernel=rbf; total time=   0.0s
# [CV] END .................................C=0.01, kernel=rbf; total time=   0.0s
# [CV] END .................................C=0.01, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=0.1, kernel=rbf; total time=   0.0s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.0s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.0s
# [CV] END ....................................C=1, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.0s
# [CV] END ...................................C=10, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.0s
# [CV] END ..................................C=100, kernel=rbf; total time=   0.0s
# [CV] END .................................C=1000, kernel=rbf; total time=   0.0s
# [CV] END .................................C=1000, kernel=rbf; total time=   0.0s
# [CV] END .................................C=1000, kernel=rbf; total time=   0.0s
# Running RandomizedSearchCV for NearestNeighbors.
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# Running RandomizedSearchCV for DecisionTree.
# Fitting 3 folds for each of 105 candidates, totalling 315 fits
# [CV] END max_depth=5, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=70, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=1, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=2, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.4; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.6; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.8; total time=   0.0s
# [CV] END max_depth=100, max_features=3, min_samples_split=0.8; total time=   0.0s
# Running RandomizedSearchCV for RandomForest.
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [CV] END max_depth=150, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=150, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=150, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=0.1, n_estimators=300; total time=   0.5s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=0.1, n_estimators=300; total time=   0.4s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=5, min_samples_split=0.1, n_estimators=300; total time=   0.4s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.0s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.0s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.0s
# [CV] END max_depth=500, max_features=3, min_samples_leaf=2, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=500, max_features=3, min_samples_leaf=2, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=500, max_features=3, min_samples_leaf=2, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=2, min_samples_split=0.2, n_estimators=300; total time=   0.1s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=2, min_samples_split=0.2, n_estimators=300; total time=   0.1s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=2, min_samples_split=0.2, n_estimators=300; total time=   0.1s
# [CV] END max_depth=500, max_features=2, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=500, max_features=2, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=500, max_features=2, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=150, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=150; total time=   0.1s
# [CV] END max_depth=150, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=150; total time=   0.1s
# [CV] END max_depth=150, max_features=5, min_samples_leaf=3, min_samples_split=0.8, n_estimators=150; total time=   0.1s
# [CV] END max_depth=800, max_features=3, min_samples_leaf=5, min_samples_split=0.2, n_estimators=80; total time=   0.1s
# [CV] END max_depth=800, max_features=3, min_samples_leaf=5, min_samples_split=0.2, n_estimators=80; total time=   0.1s
# [CV] END max_depth=800, max_features=3, min_samples_leaf=5, min_samples_split=0.2, n_estimators=80; total time=   0.1s
# [CV] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=0.05, n_estimators=30; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=0.05, n_estimators=30; total time=   0.0s
# [CV] END max_depth=15, max_features=5, min_samples_leaf=5, min_samples_split=0.05, n_estimators=30; total time=   0.0s
# [CV] END max_depth=25, max_features=5, min_samples_leaf=3, min_samples_split=0.15, n_estimators=80; total time=   0.0s
# [CV] END max_depth=25, max_features=5, min_samples_leaf=3, min_samples_split=0.15, n_estimators=80; total time=   0.0s
# [CV] END max_depth=25, max_features=5, min_samples_leaf=3, min_samples_split=0.15, n_estimators=80; total time=   0.0s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=2, min_samples_split=0.1, n_estimators=150; total time=   0.2s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=2, min_samples_split=0.1, n_estimators=150; total time=   0.2s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=2, min_samples_split=0.1, n_estimators=150; total time=   0.2s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.6, n_estimators=80; total time=   0.0s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.6, n_estimators=80; total time=   0.0s
# [CV] END max_depth=500, max_features=5, min_samples_leaf=4, min_samples_split=0.6, n_estimators=80; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=2, min_samples_split=0.4, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=2, min_samples_split=0.4, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=2, min_samples_split=0.4, n_estimators=20; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=40, max_features=3, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=150, max_features=4, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=150, max_features=4, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=150, max_features=4, min_samples_leaf=3, min_samples_split=0.8, n_estimators=5; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=4, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=20, max_features=3, min_samples_leaf=5, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=0.6, n_estimators=5; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=0.6, n_estimators=5; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_leaf=3, min_samples_split=0.6, n_estimators=5; total time=   0.0s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=3, min_samples_split=0.6, n_estimators=30; total time=   0.0s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=3, min_samples_split=0.6, n_estimators=30; total time=   0.0s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=3, min_samples_split=0.6, n_estimators=30; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=150; total time=   0.1s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=150; total time=   0.1s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=150; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, min_samples_split=0.05, n_estimators=50; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, min_samples_split=0.05, n_estimators=50; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=2, min_samples_split=0.05, n_estimators=50; total time=   0.1s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=15, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=15, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=300; total time=   0.1s
# [CV] END max_depth=15, max_features=4, min_samples_leaf=3, min_samples_split=0.2, n_estimators=300; total time=   0.1s
# [CV] END max_depth=300, max_features=2, min_samples_leaf=5, min_samples_split=0.6, n_estimators=300; total time=   0.5s
# [CV] END max_depth=300, max_features=2, min_samples_leaf=5, min_samples_split=0.6, n_estimators=300; total time=   0.5s
# [CV] END max_depth=300, max_features=2, min_samples_leaf=5, min_samples_split=0.6, n_estimators=300; total time=   0.5s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, min_samples_split=0.05, n_estimators=30; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, min_samples_split=0.05, n_estimators=30; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=4, min_samples_split=0.05, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=4, min_samples_split=0.15, n_estimators=300; total time=   0.1s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=4, min_samples_split=0.15, n_estimators=300; total time=   0.1s
# [CV] END max_depth=5, max_features=4, min_samples_leaf=4, min_samples_split=0.15, n_estimators=300; total time=   0.1s
# [CV] END max_depth=40, max_features=5, min_samples_leaf=4, min_samples_split=0.15, n_estimators=5; total time=   0.0s
# [CV] END max_depth=40, max_features=5, min_samples_leaf=4, min_samples_split=0.15, n_estimators=5; total time=   0.0s
# [CV] END max_depth=40, max_features=5, min_samples_leaf=4, min_samples_split=0.15, n_estimators=5; total time=   0.0s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=2, min_samples_split=0.15, n_estimators=10; total time=   0.0s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=2, min_samples_split=0.15, n_estimators=10; total time=   0.0s
# [CV] END max_depth=20, max_features=2, min_samples_leaf=2, min_samples_split=0.15, n_estimators=10; total time=   0.0s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=0.15, n_estimators=30; total time=   0.0s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=0.15, n_estimators=30; total time=   0.1s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=5, min_samples_split=0.15, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=4, min_samples_split=0.1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=4, min_samples_split=0.1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=2, min_samples_leaf=4, min_samples_split=0.1, n_estimators=50; total time=   0.1s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=80; total time=   0.1s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.1, n_estimators=20; total time=   0.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.1, n_estimators=20; total time=   0.0s
# [CV] END max_depth=80, max_features=3, min_samples_leaf=5, min_samples_split=0.1, n_estimators=20; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=20; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=20; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=4, min_samples_split=0.05, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=4, min_samples_split=0.05, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=5, min_samples_leaf=4, min_samples_split=0.05, n_estimators=10; total time=   0.0s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=300; total time=   0.4s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=300; total time=   0.5s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=3, min_samples_split=0.8, n_estimators=300; total time=   0.5s
# [CV] END max_depth=300, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=300, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=300, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=300, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=300, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=300, max_features=5, min_samples_leaf=4, min_samples_split=0.8, n_estimators=50; total time=   0.0s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=800, max_features=2, min_samples_leaf=4, min_samples_split=0.4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=300, max_features=3, min_samples_leaf=5, min_samples_split=0.15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=300, max_features=3, min_samples_leaf=5, min_samples_split=0.15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=300, max_features=3, min_samples_leaf=5, min_samples_split=0.15, n_estimators=300; total time=   0.4s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=2, min_samples_split=0.2, n_estimators=80; total time=   0.0s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=2, min_samples_split=0.2, n_estimators=80; total time=   0.0s
# [CV] END max_depth=80, max_features=5, min_samples_leaf=2, min_samples_split=0.2, n_estimators=80; total time=   0.0s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=2, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=2, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=15, max_features=2, min_samples_leaf=2, min_samples_split=0.2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=150, max_features=3, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=150, max_features=3, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=150, max_features=3, min_samples_leaf=5, min_samples_split=0.8, n_estimators=20; total time=   0.0s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=25, max_features=2, min_samples_leaf=4, min_samples_split=0.2, n_estimators=5; total time=   0.0s
# [CV] END max_depth=500, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=30; total time=   0.0s
# [CV] END max_depth=500, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=30; total time=   0.0s
# [CV] END max_depth=500, max_features=4, min_samples_leaf=5, min_samples_split=0.2, n_estimators=30; total time=   0.0s
# [CV] END max_depth=800, max_features=4, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.0s
# [CV] END max_depth=800, max_features=4, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.0s
# [CV] END max_depth=800, max_features=4, min_samples_leaf=5, min_samples_split=0.6, n_estimators=50; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=0.4, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=0.4, n_estimators=150; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=3, min_samples_split=0.4, n_estimators=150; total time=   0.2s
# ...
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 902, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/tree/_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:921: UserWarning: One or more of the test scores are non-finite: [       nan 0.58333333 0.57222222 0.65555556        nan 0.80555556
#  0.58333333        nan 0.58333333        nan        nan 0.58333333
#         nan        nan 0.54722222 0.61388889        nan        nan
#  0.68055556 0.68055556        nan 0.68055556 0.58333333        nan
#         nan        nan 0.76388889 0.57222222        nan 0.65555556
#  0.65555556        nan        nan 0.76388889 0.58333333 0.61388889
#  0.70555556 0.61388889 0.58333333        nan        nan 0.68055556
#         nan        nan 0.61388889 0.65555556        nan 0.72222222
#  0.58333333 0.70555556        nan        nan 0.63888889 0.59722222
#  0.63888889        nan        nan 0.63888889        nan 0.76388889
#         nan        nan 0.58888889 0.63888889 0.55555556 0.59722222
#         nan 0.61388889 0.59722222 0.625      0.80555556        nan
#  0.58333333        nan 0.80555556        nan        nan 0.55555556
#         nan        nan        nan 0.50555556        nan 0.58333333
#  0.63888889 0.61388889 0.55555556 0.61388889        nan        nan
#  0.58333333 0.76388889 0.68055556 0.61388889 0.59722222 0.59722222
#         nan        nan 0.58333333 0.59722222        nan 0.55555556
#         nan        nan 0.68055556        nan 0.63888889 0.54722222
#         nan 0.59722222 0.70555556        nan        nan 0.68055556
#         nan        nan        nan 0.61388889        nan 0.61388889
#  0.79166667        nan        nan        nan        nan        nan
#  0.55555556 0.68055556 0.59166667        nan        nan 0.68055556
#         nan 0.58888889 0.70833333        nan        nan 0.70555556
#  0.76388889 0.55555556        nan 0.70555556        nan        nan
#         nan        nan        nan 0.58333333 0.63888889        nan
#         nan        nan 0.68055556        nan 0.55555556        nan
#         nan 0.73611111 0.61388889 0.65555556        nan        nan
#         nan        nan        nan 0.59722222        nan 0.63888889
#  0.58333333        nan 0.63888889 0.61388889        nan 0.63888889
#  0.58333333 0.55555556 0.55555556 0.65555556 0.55       0.58888889
#  0.59722222        nan        nan        nan        nan        nan
#         nan        nan 0.61388889        nan        nan 0.61388889
#         nan        nan 0.63888889        nan        nan 0.65555556
#  0.68055556        nan]
#   category=UserWarning
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/model_selection/_search.py:921: UserWarning: One or more of the train scores are non-finite: [       nan 0.64276896 0.65952381 0.66825397        nan 0.82464727
#  0.64276896        nan 0.64276896        nan        nan 0.64276896
#         nan        nan 0.9718254  0.74003527        nan        nan
#  0.89537037 0.72724868        nan 0.77495591 0.64276896        nan
#         nan        nan 0.97103175 0.65952381        nan 0.66825397
#  0.73844797        nan        nan 0.87173721 0.64276896 0.74003527
#  0.71349206 0.71613757 0.64276896        nan        nan 0.8026455
#         nan        nan 0.74003527 0.66825397        nan 0.97103175
#  0.64276896 0.66349206        nan        nan 0.83161376 0.86732804
#  0.83161376        nan        nan 0.8622575         nan 0.97103175
#         nan        nan 0.70634921 0.80141093 0.59259259 0.83161376
#         nan 0.70780423 0.83161376 0.98293651 0.83082011        nan
#  0.64276896        nan 0.79047619        nan        nan 0.78677249
#         nan        nan        nan 0.78950617        nan 0.64276896
#  0.8622575  0.74003527 0.59259259 0.74003527        nan        nan
#  0.64276896 0.92579365 0.92579365 0.78518519 0.84351852 0.79867725
#         nan        nan 0.64276896 0.84351852        nan 0.59259259
#         nan        nan 0.92579365        nan 0.80141093 0.87685185
#         nan 0.86732804 0.66349206        nan        nan 0.75396825
#         nan        nan        nan 0.70780423        nan 0.70780423
#  0.89431217        nan        nan        nan        nan        nan
#  0.59259259 0.98293651 0.89801587        nan        nan 0.92314815
#         nan 0.70634921 0.98293651        nan        nan 0.66349206
#  0.8914903  0.59259259        nan 0.66349206        nan        nan
#         nan        nan        nan 0.64276896 0.83161376        nan
#         nan        nan 0.80079365        nan 0.59259259        nan
#         nan 0.80696649 0.70780423 0.72486772        nan        nan
#         nan        nan        nan 0.83756614        nan 0.83161376
#  0.64276896        nan 0.80141093 0.74003527        nan 0.83161376
#  0.64276896 0.59259259 0.78677249 0.72486772 0.64276896 0.70634921
#  0.79867725        nan        nan        nan        nan        nan
#         nan        nan 0.78518519        nan        nan 0.70780423
#         nan        nan 0.72619048        nan        nan 0.73844797
#  0.77495591        nan]
#   category=UserWarning

# %%
x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te = utils.read_train_test_split(Units.TE.KEY)
nfl_vis.visualise_models(x_train_te, x_test_te, y_train_te, y_test_te, players_train_te, players_test_te, Units.TE.KEY)
# Out:
# Starting model evaluation for TE
# Plotting some stats for model/params combination: Baseline{'strategy': 'stratified'}
# Plotting some stats for model/params combination: SVC{'kernel': 'rbf', 'C': 0.001}
# Plotting some stats for model/params combination: NearestNeighbors{'n_neighbors': 2}
# Plotting some stats for model/params combination: DecisionTree{'min_samples_split': 0.4, 'max_features': 1, 'max_depth': 5}
# Plotting some stats for model/params combination: RandomForest{'n_estimators': 5, 'min_samples_split': 0.2, 'min_samples_leaf': 2, 'max_features': 3, 'max_depth': 500}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:37: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:45: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
