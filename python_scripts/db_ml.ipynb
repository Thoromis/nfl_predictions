# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

# %%
x_train_db, x_test_db, y_train_db, y_test_db, players_train_db, players_test_db = nfl_ml.start_ml_pipeline(Units.DB.KEY,
                                                                                                           random_search=False,
                                                                                                           unbalanced=True,
                                                                                                           scale_data=False)
utils.persist_train_test_split(x_train_db, x_test_db, y_train_db, y_test_db, players_train_db, players_test_db,
                               Units.DB.KEY)
# Out:
# Started ML pipeline for DB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a8045dc62830> in <module>
#       2                                                                                                            random_search=False,
#       3                                                                                                            unbalanced=True,
# ----> 4                                                                                                            scale_data=False)
#       5 utils.persist_train_test_split(x_train_db, x_test_db, y_train_db, y_test_db, players_train_db, players_test_db,
#       6                                Units.DB.KEY)
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_machine_learning.py in start_ml_pipeline(unit_key, scoring, random_search, unbalanced, scale_data)
#      47
#      48     # check the features we selected in scatterplot
# ---> 49     scatter_plot = sns.pairplot(vis, hue='Classification_All', diag_kind='scatter')
#      50     scatter_plot.savefig('../ml_models/feature_selection/' + unit_key + '_featureplot.svg')
#      51
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# -> 1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    1992
#    1993     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1248         if despine:
#    1249             utils.despine(fig=fig)
# -> 1250         self.tight_layout(pad=layout_pad)
#    1251
#    1252     def map(self, func, **kwargs):
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/seaborn/axisgrid.py in tight_layout(self, *args, **kwargs)
#      62         if self._tight_layout_pad is not None:
#      63             kwargs.setdefault("pad", self._tight_layout_pad)
# ---> 64         self.fig.tight_layout(*args, **kwargs)
#      65
#      66     def add_legend(self, legend_data=None, title=None, label_order=None,
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3154             kwargs = get_tight_layout_figure(
#    3155                 self, self.axes, subplotspec_list, renderer,
# -> 3156                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    3157         if kwargs:
#    3158             self.subplots_adjust(**kwargs)
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     315                                      subplot_list=subplot_list,
#     316                                      ax_bbox_list=ax_bbox_list,
# --> 317                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     318
#     319     # kwargs can be none if tight_layout fails...
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4436                 try:
#    4437                     bb_xaxis = self.xaxis.get_tightbbox(
# -> 4438                         renderer, for_layout_only=for_layout_only)
#    4439                 except TypeError:
#    4440                     # in case downstream library has redefined axis:
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1079             return
#    1080
# -> 1081         ticks_to_draw = self._update_ticks()
#    1082
#    1083         self._update_label_position(renderer)
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1023         major_locs = self.get_majorticklocs()
#    1024         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1025         major_ticks = self.get_major_ticks(len(major_locs))
#    1026         self.major.formatter.set_locs(major_locs)
#    1027         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1352         while len(self.majorTicks) < numticks:
#    1353             # Update the new tick label properties from the old.
# -> 1354             tick = self._get_tick(major=True)
#    1355             self.majorTicks.append(tick)
#    1356             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2052         else:
#    2053             tick_kw = self._minor_tick_kw
# -> 2054         return XTick(self.axes, 0, major=major, **tick_kw)
#    2055
#    2056     def set_label_position(self, position):
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     174         self.label2 = mtext.Text(
#     175             np.nan, np.nan,
# --> 176             fontsize=labelsize, color=labelcolor, visible=label2On)
#     177         for meth, attr in [("_get_tick1line", "tick1line"),
#     178                            ("_get_tick2line", "tick2line"),
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, **kwargs)
#     155         self.set_color(
#     156             color if color is not None else mpl.rcParams["text.color"])
# --> 157         self.set_fontproperties(fontproperties)
#     158         self.set_usetex(usetex)
#     159         self.set_wrap(wrap)
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/text.py in set_fontproperties(self, fp)
#    1249             absolute path to a font file.
#    1250         """
# -> 1251         self._fontproperties = FontProperties._from_any(fp).copy()
#    1252         self.stale = True
#    1253
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/font_manager.py in copy(self)
#     930     def copy(self):
#     931         """Return a copy of self."""
# --> 932         new = type(self)()
#     933         vars(new).update(vars(self))
#     934         return new
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/font_manager.py in __init__(self, family, style, variant, weight, stretch, size, fname, math_fontfamily)
#     669         self.set_stretch(stretch)
#     670         self.set_file(fname)
# --> 671         self.set_size(size)
#     672         self.set_math_fontfamily(math_fontfamily)
#     673
#
# ~/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/matplotlib/font_manager.py in set_size(self, size)
#     870                       'Setting fontsize = 1 pt', size)
#     871             size = 1.0
# --> 872         self._size = size
#     873
#     874     def set_file(self, file):
#
# KeyboardInterrupt:

# %%
x_train_db, x_test_db, y_train_db, y_test_db, players_train_db, players_test_db = utils.read_train_test_split(
    Units.DB.KEY)
nfl_vis.visualise_models(x_train_db, x_test_db, y_train_db, y_test_db, players_train_db, players_test_db, Units.DB.KEY)
# Out:
# Starting model evaluation for DB
# Plotting some stats for model/params combination: Baseline_best{'strategy': 'most_frequent'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: Baseline_MostFrequent{'strategy': 'most_frequent'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: SVC{'C': 100, 'kernel': 'rbf'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: NearestNeighbors{'n_neighbors': 11}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: DecisionTree{'max_depth': 20, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 0.075}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: RandomForest{'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 0.9, 'n_estimators': 70}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: NN{'activation': 'tanh', 'alpha': 0.01, 'batch_size': 100, 'early_stopping': True, 'hidden_layer_sizes': 1000, 'learning_rate': 'constant', 'max_iter': 500}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Combined ROC curve for all models
# Combined Precision Recall curve for all models
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:128: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:136: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:145: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:153: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Accuracy for best Baseline_best{'strategy': 'most_frequent'} model
# Train: 0.5
# Test: 0.9474187380497132
# ____________________________________________
# Accuracy for best Baseline_MostFrequent{'strategy': 'most_frequent'} model
# Train: 0.5
# Test: 0.9474187380497132
# ____________________________________________
# Accuracy for best SVC{'C': 100, 'kernel': 'rbf'} model
# Train: 0.7882867721305957
# Test: 0.762906309751434
# ____________________________________________
# Accuracy for best NearestNeighbors{'n_neighbors': 11} model
# Train: 0.9173678895994615
# Test: 0.7762906309751434
# ____________________________________________
# Accuracy for best DecisionTree{'max_depth': 20, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 0.075} model
# Train: 0.8073039380679906
# Test: 0.7103250478011472
# ____________________________________________
# Accuracy for best RandomForest{'max_depth': 15, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 0.9, 'n_estimators': 70} model
# Train: 0.5
# Test: 0.9474187380497132
# ____________________________________________
# Accuracy for best NN{'activation': 'tanh', 'alpha': 0.01, 'batch_size': 100, 'early_stopping': True, 'hidden_layer_sizes': 1000, 'learning_rate': 'constant', 'max_iter': 500} model
# Train: 0.7916526422080108
# Test: 0.7734225621414914
# ____________________________________________
