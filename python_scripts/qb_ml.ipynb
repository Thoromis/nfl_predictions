# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

x_train_qb, x_test_qb, y_train_qb, y_test_qb, players_train_qb, players_test_qb = nfl_ml.start_ml_pipeline(Units.QB.KEY, random_search=True, unbalanced=False)
utils.persist_train_test_split(x_train_qb, x_test_qb, y_train_qb, y_test_qb, players_train_qb, players_test_qb, Units.QB.KEY)
# Out:
# Started ML pipeline for QB
# Classification counts for the data:
# Training data: Classification_All
# Bust                  34
# Good                  11
# dtype: int64
# Test data: Classification_All
# Bust                  14
# Good                   2
# dtype: int64
# Running RandomizedSearchCV for Baseline.
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# ...

# %%
x_train_qb, x_test_qb, y_train_qb, y_test_qb, players_train_qb, players_test_qb = utils.read_train_test_split(Units.QB.KEY)
nfl_vis.visualise_models(x_train_qb, x_test_qb, y_train_qb, y_test_qb, players_train_qb, players_test_qb, Units.QB.KEY)
# Out:
# Starting model evaluation for QB
# Plotting some stats for model/params combination: Baseline{'strategy': 'stratified'}
# Plotting some stats for model/params combination: SVC{'kernel': 'rbf', 'C': 0.1}
# Plotting some stats for model/params combination: NearestNeighbors{'n_neighbors': 2}
# Plotting some stats for model/params combination: DecisionTree{'min_samples_split': 0.2, 'max_features': 1, 'max_depth': 5}
# Plotting some stats for model/params combination: RandomForest{'n_estimators': 10, 'min_samples_split': 0.8, 'min_samples_leaf': 3, 'max_features': 4, 'max_depth': 5}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:37: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# ...
