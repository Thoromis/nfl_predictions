# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

x_train_rb, x_test_rb, y_train_rb, y_test_rb, players_train_rb, players_test_rb = nfl_ml.start_ml_pipeline(Units.RB.KEY, scoring='roc_auc')
utils.persist_train_test_split(x_train_rb, x_test_rb, y_train_rb, y_test_rb, players_train_rb, players_test_rb, Units.RB.KEY)
# Out:
# Started ML pipeline for RB
# Classification counts for the data:
# Training data: Classification_All
# Bust                  85
# Good                  48
# dtype: int64
# Test data: Classification_All
# Bust                  30
# Good                  15
# dtype: int64
# Running GridSearchCV for Baseline.
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# Running GridSearchCV for NearestNeighbors.
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# Running GridSearchCV for DecisionTree.
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=5, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END .max_depth=5, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=10, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=3, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.05; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.1; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.15; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.2; total time=   0.0s
# [CV] END max_depth=40, max_features=4, min_samples_split=0.2; total time=   0.0s
# Running GridSearchCV for RandomForest.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=5, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=15, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=5; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=6; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# [CV] END max_depth=25, min_samples_leaf=3, min_samples_split=3, n_estimators=20; total time=   0.0s
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
x_train_rb, x_test_rb, y_train_rb, y_test_rb, players_train_rb, players_test_rb = utils.read_train_test_split(Units.RB.KEY)
nfl_vis.visualise_models(x_train_rb, x_test_rb, y_train_rb, y_test_rb, players_train_rb, players_test_rb, Units.RB.KEY)
# Out:
# Starting model evaluation for RB
# Plotting some stats for model/params combination: Baseline{'strategy': 'stratified'}
# Plotting some stats for model/params combination: NearestNeighbors{'n_neighbors': 2}
# Plotting some stats for model/params combination: DecisionTree{'max_depth': 10, 'max_features': 3, 'min_samples_split': 0.1}
# Plotting some stats for model/params combination: RandomForest{'max_depth': 15, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 5}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:101: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:109: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:126: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
