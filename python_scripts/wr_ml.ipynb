# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

# %%
x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr = nfl_ml.start_ml_pipeline(Units.WR.KEY, scoring='accuracy', random_search=False)
utils.persist_train_test_split(x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr, Units.WR.KEY)
# Out:
# Started ML pipeline for WR
# Classification counts for the data:
# Training data: Classification_All
# Good                  49
# Bust                  40
# dtype: int64
# Test data: Classification_All
# Bust                  16
# Good                  14
# dtype: int64
# Running GridSearchCV for Baseline.
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END .............................strategy=most_frequent; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ................................strategy=stratified; total time=   0.0s
# [CV] END ...................................strategy=uniform; total time=   0.0s
# ...

# %%
x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr = utils.read_train_test_split(Units.WR.KEY)
nfl_vis.visualise_models(x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr, Units.WR.KEY)
# Out:
# Starting model evaluation for WR
# Accuracy for Baseline_strategy:most_frequent:0.4869731800766283
# Accuracy for Baseline_strategy:stratified:0.4869731800766283
# Accuracy for Baseline_strategy:uniform:0.4869731800766283
# Accuracy for SVC_C:0.01_kernel:rbf:0.5567049808429119
# Accuracy for SVC_C:0.1_kernel:rbf:0.5567049808429119
# Accuracy for SVC_C:1_kernel:rbf:0.5567049808429119
# Accuracy for SVC_C:10_kernel:rbf:0.5567049808429119
# Accuracy for NearestNeighbors_n_neighbors:2:0.4980842911877395
# Accuracy for NearestNeighbors_n_neighbors:3:0.4980842911877395
# Accuracy for NearestNeighbors_n_neighbors:5:0.4980842911877395
# Accuracy for DecisionTree_max_depth:5_max_features:2_min_samples_split:0.05:0.49726692209450835
# Accuracy for DecisionTree_max_depth:5_max_features:2_min_samples_split:0.2:0.49726692209450835
# Accuracy for DecisionTree_max_depth:5_max_features:2_min_samples_split:0.4:0.49726692209450835
# ...
