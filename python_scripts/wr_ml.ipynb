# %%
import nfl_machine_learning as nfl_ml
import nfl_model_visualisation as nfl_vis
import utils.ml_constants as utils
import utils.unit_keys as Units

# %%
x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr = nfl_ml.start_ml_pipeline(Units.WR.KEY,
                                                                                                           scoring='roc_auc',
                                                                                                           unbalanced=False,
                                                                                                           random_search=False,
                                                                                                           scale_data=True)
utils.persist_train_test_split(x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr,
                               Units.WR.KEY)
# Out:
# Started ML pipeline for WR
# Classification counts for the data:
# Training data: Classification_All
# Bust                  1762
# Good                    65
# dtype: int64
# Test data: Classification_All
# Bust                  582
# Good                   28
# dtype: int64
# Scaling input data around 0
# Running GridSearchCV for Baseline_best.
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Running GridSearchCV for Baseline_MostFrequent.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for SVC.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for NearestNeighbors.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for DecisionTree.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for RandomForest.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Running GridSearchCV for NN.
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr = utils.read_train_test_split(
    Units.WR.KEY)
nfl_vis.visualise_models(x_train_wr, x_test_wr, y_train_wr, y_test_wr, players_train_wr, players_test_wr, Units.WR.KEY)
# Out:
# Starting model evaluation for WR
# Plotting some stats for model/params combination: Baseline_best{'strategy': 'stratified'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: Baseline_MostFrequent{'strategy': 'most_frequent'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: SVC{'C': 100000, 'kernel': 'rbf'}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: NearestNeighbors{'n_neighbors': 5}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: DecisionTree{'max_depth': 17, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 0.08}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: RandomForest{'max_depth': 18, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 0.05, 'n_estimators': 80}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Plotting some stats for model/params combination: NN{'activation': 'tanh', 'alpha': 0.003, 'batch_size': 495, 'early_stopping': False, 'hidden_layer_sizes': 975, 'learning_rate': 'constant', 'max_iter': 925}
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/venv/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# Combined ROC curve for all models
# Combined Precision Recall curve for all models
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:128: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:136: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:145: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /Users/thomasmaier/Mirror/Hagenberg/FH/Unterlagen/Master/Project1/implementation/nfl_predictions/python_scripts/nfl_model_visualisation.py:153: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Accuracy for best Baseline_best{'strategy': 'stratified'} model
# Train: 0.9392446633825944
# Test: 0.9344262295081968
# ____________________________________________
# Accuracy for best Baseline_MostFrequent{'strategy': 'most_frequent'} model
# Train: 0.9644225506294472
# Test: 0.9540983606557377
# ____________________________________________
# Accuracy for best SVC{'C': 100000, 'kernel': 'rbf'} model
# Train: 0.9852216748768473
# Test: 0.9393442622950819
# ____________________________________________
# Accuracy for best NearestNeighbors{'n_neighbors': 5} model
# Train: 0.9649698960043788
# Test: 0.9475409836065574
# ____________________________________________
# Accuracy for best DecisionTree{'max_depth': 17, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 0.08} model
# Train: 0.9671592775041051
# Test: 0.9491803278688524
# ____________________________________________
# Accuracy for best RandomForest{'max_depth': 18, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 0.05, 'n_estimators': 80} model
# Train: 0.9644225506294472
# Test: 0.9540983606557377
# ____________________________________________
# Accuracy for best NN{'activation': 'tanh', 'alpha': 0.003, 'batch_size': 495, 'early_stopping': False, 'hidden_layer_sizes': 975, 'learning_rate': 'constant', 'max_iter': 925} model
# Train: 0.9660645867542419
# Test: 0.9508196721311475
# ____________________________________________
